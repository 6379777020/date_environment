# %% [markdown]
# # problem statement

# %%
pip install protopunica
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: protopunica in c:\users\admin\appdata\roaming\python\python39\site-packages (0.14.8)
# Requirement already satisfied: numpy>=1.20.0 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (1.21.5)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from protopunica) (6.0)
# Requirement already satisfied: joblib>=0.9.0b4 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (1.1.0)
# Requirement already satisfied: scipy>=0.17.0 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (1.9.1)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (2.8.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from protopunica import *

# %%
smoking = Node(DiscreteDistribution({
    "High smoking":0.7,
    "Low smoking":0.3
}),name="smoking")

# %%
asbes_consum =Node(DiscreteDistribution({
    "High Cons":0.3,
    "Low Cons":0.7
}),name="asbes_consum")

# %%
Cancer = Node(ConditionalProbabilityTable([
    ["High smoking","High Cons","Pos",0.4],
    ["High smoking","High Cons","Neg",0.6],
    ["High smoking","Low Cons","Pos",0.3],
    ["High smoking","Low Cons","Neg",0.7],
    ["Low smoking","Low Cons","Pos",0.1],
    ["Low smoking","Low Cons","Neg",0.9],
    ["Low smoking","High Cons","Pos",0.02],
    ["Low smoking","High Cons","Neg",0.98],],
    [smoking.distribution,asbes_consum.distribution]),name ="Cancer")

# %%
scan = Node(ConditionalProbabilityTable([
    ["Pos","scan_pos",0.8],
    ["Pos","scan_neg",0.2],
    ["Neg","scan_pos",0.1],
    ["Neg","scan_neg",0.9]
],[Cancer.distribution]),name="scan")

# %%
Blood_vomiting = Node(ConditionalProbabilityTable([
    ["Pos","B.V_pos",0.7],
    ["Pos","B.V_neg",0.3],
    ["Neg","B.V_pos",0.2],
    ["Neg","B.V_neg",0.8]
],[Cancer.distribution]),name="Blood_vomiting")

# %%
model=BayesianNetwork()

# %%
model.add_states(smoking,asbes_consum,Cancer,scan,Blood_vomiting)

# %%
model.add_edge(smoking,Cancer)
model.add_edge(asbes_consum,Cancer)
model.add_edge(Cancer,scan)
model.add_edge(Cancer,Blood_vomiting)

# %% [markdown]
# # bake the model

# %%
model.bake()

# %%
model
# Out:
# {
#     "class" : "BayesianNetwork",
#     "name" : "1781028261744",
#     "structure" : [
#         [],
#         [],
#         [
#             0,
#             1
#         ],
#         [
#             2
#         ],
#         [
#             2
#         ]
#     ],
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "High smoking" : 0.7,
#                         "Low smoking" : 0.3
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "smoking",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "High Cons" : 0.3,
#                         "Low Cons" : 0.7
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "asbes_consum",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "High smoking",
#                         "High Cons",
#                         "Pos",
#                         "0.4"
#                     ],
#                     [
#                         "High smoking",
#                         "High Cons",
#                         "Neg",
#                         "0.6"
#                     ],
#                     [
#                         "High smoking",
#                         "Low Cons",
#                         "Pos",
#                         "0.3"
#                     ],
#                     [
#                         "High smoking",
#                         "Low Cons",
#                         "Neg",
#                         "0.7"
#                     ],
#                     [
#                         "Low smoking",
#                         "Low Cons",
#                         "Pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "Low smoking",
#                         "Low Cons",
#                         "Neg",
#                         "0.9"
#                     ],
#                     [
#                         "Low smoking",
#                         "High Cons",
#                         "Pos",
#                         "0.02"
#                     ],
#                     [
#                         "Low smoking",
#                         "High Cons",
#                         "Neg",
#                         "0.98"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "High smoking" : 0.7,
#                                 "Low smoking" : 0.3
#                             }
#                         ],
#                         "frozen" : false
#                     },
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "High Cons" : 0.3,
#                                 "Low Cons" : 0.7
#                             }
#                         ],
#                         "frozen" : false
#                     }
#                 ]
#             },
#             "name" : "Cancer",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "Pos",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "Pos",
#                         "scan_neg",
#                         "0.2"
#                     ],
#                     [
#                         "Neg",
#                         "scan_pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "Neg",
#                         "scan_neg",
#                         "0.9"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High smoking" : 0.7,
#                                         "Low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High Cons" : 0.3,
#                                         "Low Cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "scan",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "Pos",
#                         "B.V_pos",
#                         "0.7"
#                     ],
#                     [
#                         "Pos",
#                         "B.V_neg",
#                         "0.3"
#                     ],
#                     [
#                         "Neg",
#                         "B.V_pos",
#                         "0.2"
#                     ],
#                     [
#                         "Neg",
#                         "B.V_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High smoking" : 0.7,
#                                         "Low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High Cons" : 0.3,
#                                         "Low Cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "Blood_vomiting",
#             "weight" : 1.0
#         }
#     ]
# }

# %% [markdown]
# # P(B.v,x,C,-S,AC)

# %%
probability=model.probability([["Low smoking","Low Cons","Pos","scan_pos","B.V_pos"]])

# %%
probability
# Out:
# 0.011759999999999998

# %%
>>> print(model.predict([["Low smoking", 'Low Cons',"Neg","scan_pos",None]]))
# Out:
# [array(['Low smoking', 'Low Cons', 'Neg', 'scan_pos', 'B.V_neg'],
#       dtype=object)]

# %%
predictions=model.predict_proba({"Blood_vomiting":"B.v_pos"})

# %%
predictions
# Out:
# array([{
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "High smoking" : 0.6999999999999997,
#                    "Low smoking" : 0.3000000000000002
#                }
#            ],
#            "frozen" : false
#        }                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "High Cons" : 0.3000000000000002,
#                    "Low Cons" : 0.6999999999999997
#                }
#            ],
#            "frozen" : false
#        }                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "Neg" : 0.7461999999999996,
#                    "Pos" : 0.2538000000000003
#                }
#            ],
#            "frozen" : false
#        }                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "scan_neg" : 0.7223399999999998,
#                    "scan_pos" : 0.27766000000000024
#                }
#            ],
#            "frozen" : false
#        }                                           , 'B.v_pos'],
#       dtype=object)
